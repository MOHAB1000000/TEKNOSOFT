# %% [markdown]
# # **Imports & Downloads**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# # **Importing The Dataset**

# %%
dataset = pd.read_csv('spam.csv',encoding='latin-1')[['v1', 'v2']]
dataset.columns = ['Y', 'X']
dataset
# Out:
#          Y                                                  X
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# # **Preprocess By Tokenizing**

# %%
#Test
text = "This is a sample text data for preprocessing. Hello World 103"

# %%
tokens = nltk.word_tokenize(text)
stop_words = stopwords.words('english')
filtered_tokens = [token for token in tokens if token not in stop_words]
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

print("Lemmatized tokens:", lemmatized_tokens)
# Out:
# Lemmatized tokens: ['This', 'sample', 'text', 'data', 'preprocessing', '.', 'Hello', 'World', '103']

# %%
def preprocess_text(textdata):
  stop_words = stopwords.words('english')
  processed_data = []

  for text in textdata:
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token not in stop_words]
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    processed_text = ' '.join(lemmatized_tokens)
    processed_data.append(processed_text)
  return processed_data

preprocessed_data = preprocess_text(dataset.X)
for i, text in enumerate(dataset.X):
  print(f"Preprocessed tokens {i+1} : {preprocessed_data[i]}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Preprocessed tokens 573 : Can open door ?
# Preprocessed tokens 574 : Waiting call .
# Preprocessed tokens 575 : Nope waiting sch 4 daddy ...
# Preprocessed tokens 576 : You ? 1,000 cash ? 2,000 prize ! To claim , call09050000327
# Preprocessed tokens 577 : I 'm tired arguing week week . Do want , 'll .
# Preprocessed tokens 578 : ÌÏ wait 4 sch finish ard 5 ..
# Preprocessed tokens 579 : mobile number å£5000 , claim call u back ring claim hot line 09050005321 .
# Preprocessed tokens 580 : Arngd marriage u r walkin unfortuntly snake bite u. bt love marriage dancing frnt snake & amp ; sayin Bite , bite .
# Preprocessed tokens 581 : Huh early .. Then Ì_ dinner outside izzit ?
# Preprocessed tokens 582 : Ok anyway need change said
# Preprocessed tokens 583 : We tried contact reply offer 750 min 150 textand new video phone call 08002988890 reply free delivery tomorrow
# Preprocessed tokens 584 : ex-wife able kid . Do want kid one day ?
# Preprocessed tokens 585 : So 's scotland . Hope showing JJC tendency . Take care . Live dream
# Preprocessed tokens 586 : Tell u headache want use 1 hour sick time .
# Preprocessed tokens 587 : I dun thk 'll quit yet ... Hmmm , go jazz ? Yogasana oso ... We go meet em lesson den ...
# Preprocessed tokens 588 : \Pete please ring meive hardly gotany credit\ '' ''
# Preprocessed tokens 589 : Ya srsly better yi tho
# Preprocessed tokens 590 : I 'm meeting , call later
# Preprocessed tokens 591 : For ur chance win å£250 wkly shopping spree TXT : SHOP 80878 . T 's & C 's www.txt-2-shop.com custcare 08715705022 , 1x150p/wk
# Preprocessed tokens 592 : You specially selected receive 2000 pound award ! Call 08712402050 BEFORE line close . Cost 10ppm . 16+ . T & Cs apply . AG Promo
# Preprocessed tokens 593 : PRIVATE ! Your 2003 Account Statement 07753741225 show 800 un-redeemed S. I. M. point . Call 08715203677 Identifier Code : 42478 Expires 24/10/04
# Preprocessed tokens 594 : You still grand prix ?
# Preprocessed tokens 595 : I met stranger choose friend . As long world stand , friendship never end . Lets Friends forever ! ! ! Gud nitz ...
# Preprocessed tokens 596 : I great ! How ?
# Preprocessed tokens 597 : Gud mrng dear nice day
# Preprocessed tokens 598 : You important customer service announcement . Call FREEPHONE 0800 542 0825 !
# Preprocessed tokens 599 : Will . Was exhausted train morning . Too much wine pie . You sleep well
# Preprocessed tokens 600 : I 'm going buy mum 's present ar .
# Preprocessed tokens 601 : Mind blastin .. No Tsunamis occur .. Rajnikant stopped swimming Indian Ocean .. : -D
# Preprocessed tokens 602 : If u sending home first 's ok lor . I 'm ready yet .
# Preprocessed tokens 603 : Speaking cash yet ?
# Preprocessed tokens 604 : Be happy . I come noon
# Preprocessed tokens 605 : Meet lunch la ...
# Preprocessed tokens 606 : TaKe CaRE n gET WeLL sOOn
# Preprocessed tokens 607 : XCLUSIVE @ CLUBSAISAI 2MOROW 28/5 SOIREE SPECIALE ZOUK WITH NICHOLS FROM PARIS.FREE ROSES 2 ALL LADIES ! ! ! info : 07946746291/07880867867
# Preprocessed tokens 608 : I meant say cant wait see u getting bored bridgwater banter
# Preprocessed tokens 609 : Neva mind 's ok ..
# Preprocessed tokens 610 : It 's fine , imma get drink somethin . Want come find ?
# Preprocessed tokens 611 : 22 day kick ! For Euro2004 U kept date latest news result daily . To removed send GET TXT STOP 83222
# Preprocessed tokens 612 : Its valentine game . . . Send dis msg ur friend . .. If 5 answer r someone really love u. Ques- colour suit best ? rply
# Preprocessed tokens 613 : I many dependent
# Preprocessed tokens 614 : THANX4 TODAY CER IT WAS NICE 2 CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# Preprocessed tokens 615 : I called said : ) choose future .
# Preprocessed tokens 616 : \Happy valentine day\ '' I know early hundred handsomes beauty wish . So thought finish aunty uncle 1st ... ''
# Preprocessed tokens 617 : He like v shock leh . Cos telling shuhui like telling leona also . Like dat almost know liao . He got ask abt ur reaction lor .
# Preprocessed tokens 618 : For family happiness ..
# Preprocessed tokens 619 : I come n pick Ì_ ... Come immediately aft ur lesson ...
# Preprocessed tokens 620 : Let snow . Let snow . This kind weather brings ppl together friendship grow .
# Preprocessed tokens 621 : Dear got & lt ; # & gt ; dollar hi hi
# Preprocessed tokens 622 : Good word .... But word may leave u dismay many time .
# Preprocessed tokens 623 : MAKE SURE ALEX KNOWS HIS BIRTHDAY IS OVER IN FIFTEEN MINUTES AS FAR AS YOU 'RE CONCERNED
# Preprocessed tokens 624 : sorry , , got thing . may pub later .
# Preprocessed tokens 625 : Nah 's straight , bring bud drink something 's actually little useful straight cash
# Preprocessed tokens 626 : Haha good hear , I 'm officially paid market 8th
# Preprocessed tokens 627 : How many lick take get center tootsie pop ?
# Preprocessed tokens 628 : Yup thk r e teacher said make face look longer . Darren ask 2 cut short .
# Preprocessed tokens 629 : New TEXTBUDDY Chat 2 horny guy ur area 4 25p Free 2 receive Search postcode gaytextbuddy.com . TXT ONE name 89693
# Preprocessed tokens 630 : Todays Vodafone number ending 4882 selected receive å£350 award . If number match call 09064019014 receive å£350 award .
# Preprocessed tokens 631 : Please dont say like . Hi hi hi
# Preprocessed tokens 632 : Thank u !
# Preprocessed tokens 633 : Oh forwarded message . I thought send
# Preprocessed tokens 634 : Got . Seventeen pound seven hundred ml ÛÒ hope ok .
# Preprocessed tokens 635 : Dear Voucher Holder , 2 claim week offer , PC go http : //www.e-tlp.co.uk/expressoffer Ts & Cs apply.2 stop text txt STOP 80062 .
# Preprocessed tokens 636 : Me n funny ...
# Preprocessed tokens 637 : Sweetheart , hope kind day ! Have one load reason smile . Biola
# Preprocessed tokens 638 : When Ì_ login dat time ... Dad fetching Ì_ home ?
# Preprocessed tokens 639 : What shower , baby ?
# Preprocessed tokens 640 : I askd u question hour . Its answer
# Preprocessed tokens 641 : Well imma definitely need restock thanksgiving , I 'll let know I 'm
# Preprocessed tokens 642 : said kiss , kiss , ca n't sound effect ! He gorgeous man n't ! Kind person need smile brighten day !
# Preprocessed tokens 643 : Probably gon na swing wee bit
# Preprocessed tokens 644 : Ya nice . . .be ready thursday
# Preprocessed tokens 645 : Allo ! We braved bus taken train triumphed . I mean weÛ÷re bÛ÷ham . Have jolly good rest week
# Preprocessed tokens 646 : Watching cartoon , listening music & amp ; eve go temple & amp ; church .. What u ?
# Preprocessed tokens 647 : Do mind I ask happened ? You dont say uncomfortable .
# Preprocessed tokens 648 : PRIVATE ! Your 2003 Account Statement show 800 un-redeemed S. I. M. point . Call 08715203694 Identifier Code : 40533 Expires 31/10/04
# Preprocessed tokens 649 : No prob . I send email .
# Preprocessed tokens 650 : You ? 1,000 cash ? 2,000 prize ! To claim , call09050000327 . T & C : RSTM , SW7 3SS . 150ppm
# Preprocessed tokens 651 : Thats cool ! Sometimes slow gentle . Sonetimes rough hard : )
# Preprocessed tokens 652 : I 'm gon na say . Sorry . I would normal starting panic time . Sorry ! Are seeing Tuesday ?
# Preprocessed tokens 653 : Wait , know wesley town ? I bet hella drug !
# Preprocessed tokens 654 : Fine miss much .
# Preprocessed tokens 655 : Did u got person story
# Preprocessed tokens 656 : Tell drug dealer 's getting impatient
# Preprocessed tokens 657 : Sun cant come earth send luv ray . cloud cant come river send luv rain . I cant come meet U , send care msg U. Gud evng
# Preprocessed tokens 658 : You place man
# Preprocessed tokens 659 : It doesnt make sense take unless free . If need know , wikipedia.com
# Preprocessed tokens 660 : 88800 89034 premium phone service call 08718711108
# Preprocessed tokens 661 : Under sea , lay rock . In rock , envelope . In envelope , paper . On paper , 3 word ... '
# Preprocessed tokens 662 : Then mum 's repent ?
# Preprocessed tokens 663 : Sorry going home first ... Daddy come fetch Ì_ later ...
# Preprocessed tokens 664 : Leave de : - ) . Start Prepare next : - ) ..
# Preprocessed tokens 665 : Yes baby ! We study position kama sutra ; )
# Preprocessed tokens 666 : En chikku nange bakra msg kalstiya .. tea/coffee ?
# Preprocessed tokens 667 : Carlos 'll minute still need buy
# Preprocessed tokens 668 : This pay & lt ; DECIMAL & gt ; lakh : )
# Preprocessed tokens 669 : Have good evening ! Ttyl
# Preprocessed tokens 670 : Did u receive msg ?
# Preprocessed tokens 671 : Ho ho - big belly laugh ! See ya tomo
# Preprocessed tokens 672 : SMS . ac sun0819 post HELLO : \You seem cool
# Preprocessed tokens 673 : Get ur 1st RINGTONE FREE NOW ! Reply msg TONE . Gr8 TOP 20 tone phone every week å£1.50 per wk 2 opt send STOP 08452810071 16
# Preprocessed tokens 674 : Ditto . And wo n't worry saying ANYTHING anymore . Like said last night , whatever want 'll . Peace .
# Preprocessed tokens 675 : I 've got & lt ; # & gt ; , way I could pick ?
# Preprocessed tokens 676 : I dont knw pa , drink milk ..
# Preprocessed tokens 677 : Maybe ? ! Say hi find got card . Great escape wetherspoons ?
# Preprocessed tokens 678 : Piggy , r u awake ? I bet u 're still sleeping . I 'm going 4 lunch ...
# Preprocessed tokens 679 : Cause I 'm freaky lol
# Preprocessed tokens 680 : Missed call cause I yelling scrappy . Miss u . Ca n't wait u come home . I 'm lonely today .
# Preprocessed tokens 681 : What 'hex ' place talk ? Explain !
# Preprocessed tokens 682 : ÌÏ log 4 wat . It 's sdryb8i
# Preprocessed tokens 683 : Is xy going 4 e lunch ?
# Preprocessed tokens 684 : Hi I 'm sue . I 20 year old work lapdancer . I love sex . Text live - I 'm bedroom . text SUE 89555 . By TextOperator G2 1DA 150ppmsg 18+
# Preprocessed tokens 685 : I wanted ask Ì_ wait 4 finish lect . Cos lect finish hour anyway .
# Preprocessed tokens 686 : Have finished work yet ? : )
# Preprocessed tokens 687 : Every King Was Once A Crying Baby And Every Great Building Was Once A Map .. Not Imprtant Where U r TODAY , BUT Where U Wil Reach TOMORW . Gud ni8
# Preprocessed tokens 688 : Dear , Me cherthala.in case u r coming cochin pls call bfore u start.i shall also reach accordingly.or tell day u r coming.tmorow engaged an holiday .
# Preprocessed tokens 689 : Thanks love . But torch bold .
# Preprocessed tokens 690 : < Forwarded 448712404000 > Please CALL 08712404000 immediately urgent message waiting .
# Preprocessed tokens 691 : Was farm open ?
# Preprocessed tokens 692 : Sorry trouble u . Can buy 4d dad ? 1405 , 1680 , 1843 . All 2 big 1 small , sat n sun . Thanx .
# Preprocessed tokens 693 : My sister law , hope great month . Just saying hey . Abiola
# Preprocessed tokens 694 : Will purchase stuff today mail . Do po box number ?
# Preprocessed tokens 695 : Ah poop . Looks like ill prob send laptop get fixed cuz gpu problem
# Preprocessed tokens 696 : Good . Good job . I like entrepreneur
# Preprocessed tokens 697 : Aight , close still around alex 's place ?
# Preprocessed tokens 698 : meet corporation st outside gap Û_ see mind working !
# Preprocessed tokens 699 : Mum ask Ì_ buy food home ...
# Preprocessed tokens 700 : K .. u also dont msg reply msg ..
# Preprocessed tokens 701 : How much r Ì_ willing pay ?
# Preprocessed tokens 702 : Sorry , I 'll call later
# Preprocessed tokens 703 : What important prevent dehydration giving enough fluid
# Preprocessed tokens 704 : Thats bit weird , even ? - supposed happening ? But good idea , sure pub !
# Preprocessed tokens 705 : True dear .. sat pray evening felt so.so sm 'd time ...
# Preprocessed tokens 706 : I n't think I get away trek long family town , sorry
# Preprocessed tokens 707 : So wan na gym harri
# Preprocessed tokens 708 : Quite late lar ... Ard 12 anyway wun b drivin ...
# Preprocessed tokens 709 : To review KEEP fantastic Nokia N-Gage game deck Club Nokia , go 2 www.cnupdates.com/newsletter . unsubscribe alert reply word OUT
# Preprocessed tokens 710 : 4mths half price Orange line rental & latest camera phone 4 FREE . Had phone 11mths+ ? Call MobilesDirect free 08000938767 update ! or2stoptxt T & Cs
# Preprocessed tokens 711 : Height Confidence : All Aeronautics professor wer calld & amp ; wer askd 2 sit aeroplane . Aftr sat wer told dat plane w made student . Dey hurried plane .. Bt 1 didnt move ... He said : \if made student
# Preprocessed tokens 712 : It seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke
# Preprocessed tokens 713 : 08714712388 10am-7pm Cost 10p
# Preprocessed tokens 714 : Save stress . If person dorm account , send account detail money sent .
# Preprocessed tokens 715 : He also know lunch menu da . . I know
# Preprocessed tokens 716 : When stuff sell i.ll tell
# Preprocessed tokens 717 : +449071512431 URGENT ! This 2nd attempt contact U ! U WON å£1250 CALL 09071512433 b4 050703 T & CsBCM4235WC1N3XX . callcost 150ppm mobilesvary . maxå£7 . 50
# Preprocessed tokens 718 : Book lesson ? msg ... I call work sth ... I 'm going get spec . My membership PX3748
# Preprocessed tokens 719 : You WON guaranteed å£1000 cash å£2000 prize . To claim yr prize call customer service representative 08714712394 10am-7pm
# Preprocessed tokens 720 : Macha dont feel upset.i assume mindset.believe one evening wonderful plan us.LET LIFE BEGIN AGAIN.call anytime
# Preprocessed tokens 721 : Oh ? Send address
# Preprocessed tokens 722 : S'fine . Anytime . All best .
# Preprocessed tokens 723 : That wondar full flim .
# Preprocessed tokens 724 : Ya even cooky jelly
# Preprocessed tokens 725 : The world running still.maybe feeling , it.or admit , mad.then correction ? let call life.and keep running world , may u r also running.lets run .
# Preprocessed tokens 726 : Got ! It look scrumptious ... daddy want eat night long !
# Preprocessed tokens 727 : Of co lar 'm ba dao ok ... 1 pm lor ... Y u never ask go ah ... I said u would ask fri said u ask today ...
# Preprocessed tokens 728 : Alright omw , got ta change order half8th
# Preprocessed tokens 729 : Exactly . Anyways far . Is jide study visiting
# Preprocessed tokens 730 : Dunno u ask .
# Preprocessed tokens 731 : Email AlertFrom : Jeri StewartSize : 2KBSubject : Low-cost prescripiton drvgsTo listen email call 123
# Preprocessed tokens 732 : No n't . Spring coming early yay !
# Preprocessed tokens 733 : Lol wo n't feel bad I use money take steak dinner =D
# Preprocessed tokens 734 : Even u dont get trouble convincing .. tel twice tel neglect msg dont c read .. dont reply
# Preprocessed tokens 735 : Leaving qatar tonite search opportunity.all went fast.pls add ur prayer dear.Rakhesh
# Preprocessed tokens 736 : Then one talking
# Preprocessed tokens 737 : Thanks looking . I really appreciate .
# Preprocessed tokens 738 : Hi . Customer Loyalty Offer : The NEW Nokia6650 Mobile ONLY å£10 TXTAUCTION ! Txt word : START No : 81151 & get Now ! 4T & Ctxt TC 150p/MTmsg
# Preprocessed tokens 739 : Wish !
# Preprocessed tokens 740 : Haha mayb u 're rite ... U know well . Da feeling liked someone gd lor . U faster go find one gal group attached liao .
# Preprocessed tokens 741 : Yes . Glad made .
# Preprocessed tokens 742 : Do well : ) little time . Thing good time ahead :
# Preprocessed tokens 743 : Just got . room soon . Û_ . n't put clock back til 8 shouted everyone get realised 7. wahay . another hour bed .
# Preprocessed tokens 744 : Ok . There may free gym .
# Preprocessed tokens 745 : Men like shorter lady . Gaze eye .
# Preprocessed tokens 746 : Dunno jus say go lido . Same time 930 .
# Preprocessed tokens 747 : I promise take good care , princess . I run . Please send pic get chance . Ttyl !
# Preprocessed tokens 748 : U subscribed best Mobile Content Service UK å£3 per 10 day send STOP 82324 . Helpline 08706091795
# Preprocessed tokens 749 : Is reason 've spoken year ? Anyways great week best exam
# Preprocessed tokens 750 : By monday next week . Give full gist
# Preprocessed tokens 751 : Do realize 40 year , 'll thousand old lady running around tattoo ?
# Preprocessed tokens 752 : You important customer service announcement PREMIER .
# Preprocessed tokens 753 : Dont gim lip caveboy
# Preprocessed tokens 754 : When get library
# Preprocessed tokens 755 : Realy sorry-i n't recognise number confused : ) r u please ? !
# Preprocessed tokens 756 : So didnt holla ?
# Preprocessed tokens 757 : Cant think anyone * spare room * top head
# Preprocessed tokens 758 : Faith make thing possible , Hope make thing work , Love make thing beautiful , May three Christmas ! Merry Christmas !
# Preprocessed tokens 759 : U made appointment
# Preprocessed tokens 760 : Call you/carlos is/are , phone 's vibrate acting I might hear text
# Preprocessed tokens 761 : Romantic Paris . 2 night , 2 flight å£79 Book 4 next year . Call 08704439680Ts & Cs apply .
# Preprocessed tokens 762 : We grandma . Oh dear , u still ill ? I felt Shit morning think hungover ! Another night . We leave sat .
# Preprocessed tokens 763 : Urgent Ur å£500 guaranteed award still unclaimed ! Call 09066368327 NOW closingdate04/09/02 claimcode M39M51 å£1.50pmmorefrommobile2Bremoved-MobyPOBox734LS27YF
# Preprocessed tokens 764 : Nothing jus tot u would ask co u ba gua ... But went mt faber yest ... Yest jus went already mah today going ... Jus call lor ...
# Preprocessed tokens 765 : Wishing family Merry \X\ '' ma HAPPY NEW Year advance .. ''
# Preprocessed tokens 766 : UR awarded City Break could WIN å£200 Summer Shopping spree every WK . Txt STORE 88039 . SkilGme . TsCs087147403231Winawk ! Age16 å£1.50perWKsub
# Preprocessed tokens 767 : I 'm nt goin , got somethin , unless meetin 4 dinner lor ... Haha , wonder go ti time ...
# Preprocessed tokens 768 : Sorry , I 'll call later
# Preprocessed tokens 769 : I cant pick phone right . Pls send message
# Preprocessed tokens 770 : Lol I know ! They 're dramatic . Schools already closed tomorrow . Apparently ca n't drive inch snow supposed get .
# Preprocessed tokens 771 : Not getting anywhere damn job hunting !
# Preprocessed tokens 772 : Lol ! U drunkard ! Just hair moment . Yeah still 4 tonight . Wats plan ?
# Preprocessed tokens 773 : idc get , weaseling way shit twice row
# Preprocessed tokens 774 : I wil & lt ; # & gt ; minute . Got space
# Preprocessed tokens 775 : Just sleeping .. surfing
# Preprocessed tokens 776 : Thanks picking trash .
# Preprocessed tokens 777 : Why n't go tell friend 're sure want live smoke much spend hour begging come smoke
# Preprocessed tokens 778 : \Hi Kate lovely see tonight ill phone tomorrow . I got sing guy gave card ! xxx\ '' ''
# Preprocessed tokens 779 : Happy New year dear brother . I really miss . Just got number decided send text wishing happiness . Abiola
# Preprocessed tokens 780 : That mean get door
# Preprocessed tokens 781 : Your opinion ? 1 . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# Preprocessed tokens 782 : Hmmm ... I thought said 2 hour slave , 3 ... You late ... How I punish ?
# Preprocessed tokens 783 : Beerage ?
# Preprocessed tokens 784 : You important customer service announcement PREMIER . Call FREEPHONE 0800 542 0578 !
# Preprocessed tokens 785 : Dont think . It turn like randomlly within 5min opening
# Preprocessed tokens 786 : She supposed could n't make , 's still town though
# Preprocessed tokens 787 : It . Most time fix spelling . But sometimes get completely diff word . Go figure
# Preprocessed tokens 788 : Ever thought living good life perfect partner ? Just txt back NAME AGE join mobile community . ( 100p/SMS )
# Preprocessed tokens 789 : 5 Free Top Polyphonic Tones call 087018728737 , National Rate . Get toppoly tune sent every week , text SUBPOLY 81618 , å£3 per pole . UnSub 08718727870 .
# Preprocessed tokens 790 : Gud mrng dear hav nice day
# Preprocessed tokens 791 : This hoping enjoyed game yesterday . Sorry 've touch pls know fondly bein thot . Have great week . Abiola
# Preprocessed tokens 792 : All e best 4 ur driving tmr : - )
# Preprocessed tokens 793 : Y ? WHERE U AT DOGBREATH ? ITS JUST SOUNDING LIKE JAN C THATåÕS AL ! ! ! ! ! ! ! ! !
# Preprocessed tokens 794 : Omg I want scream . I weighed I lost weight ! Woohoo !
# Preprocessed tokens 795 : There generally n't one . It 's uncountable noun - u dictionary . piece research ?
# Preprocessed tokens 796 : 's really getting hanging around .
# Preprocessed tokens 797 : Orange customer , may claim FREE CAMERA PHONE upgrade loyalty . Call 0207 153 9996 . Offer end 14thMarch . T & C 's apply . Opt-out availa
# Preprocessed tokens 798 : \Petey boy whereare friendsare theKingshead come canlove Nic\ '' ''
# Preprocessed tokens 799 : Ok msg u b4 leave house .
# Preprocessed tokens 800 : \ Gim few\ '' & lt ; # & gt ; minute ago ''
# Preprocessed tokens 801 : Last Chance ! Claim ur å£150 worth discount voucher today ! Text SHOP 85023 ! SavaMob , offer mobile ! T Cs SavaMob POBOX84 , M263UZ . å£3.00 Sub . 16
# Preprocessed tokens 802 : Appt & lt ; TIME & gt ; . Not fault u n't listen . I told u twice
# Preprocessed tokens 803 : FREE 1st week ! No1 Nokia tone 4 ur mobile every week txt NOKIA 8077 Get txting tell ur mate . www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone
# Preprocessed tokens 804 : You guaranteed å£200 award even å£1000 cashto claim UR award call free 08000407165 ( 18+ ) 2 stop getstop 88222 PHP . RG21 4JX
# Preprocessed tokens 805 : K I 'll 4 .
# Preprocessed tokens 806 : I dled 3d imp
# Preprocessed tokens 807 : sure , make sure know ai n't smokin yet
# Preprocessed tokens 808 : Boooo always work . Just quit .
# Preprocessed tokens 809 : I taking half day leave bec well
# Preprocessed tokens 810 : Ugh I n't wan na get bed . It 's warm .
# Preprocessed tokens 811 : S : ) s.nervous & lt ; # & gt ; : )
# Preprocessed tokens 812 : So 's ring come guy costume . It 's gift future yowifes . Hint hint
# Preprocessed tokens 813 : Congratulations ur awarded either å£500 CD gift voucher & Free entry 2 å£100 weekly draw txt MUSIC 87066 TnCs www.Ldew.com1win150ppmx3age16
# Preprocessed tokens 814 : I borrow ur bag ok .
# Preprocessed tokens 815 : U outbid simonwatson5120 Shinco DVD Plyr . 2 bid , visit sm . ac/smsrewards 2 end bid notification , reply END OUT
# Preprocessed tokens 816 : Where 's boytoy ? I miss ... What happened ?
# Preprocessed tokens 817 : He lot used one babe , model n't help . Youi bring 'll match
# Preprocessed tokens 818 : Also bringing galileo dobby
# Preprocessed tokens 819 : Then responding
# Preprocessed tokens 820 : \BOO BABE ! U ENJOYIN YOURJOB ? U SEEMED 2 B GETTIN ON WELL HUNNY ! HOPE URE OK ? TAKE CARE & IåÕLLSPEAK 2U SOONLOTS OF LOVEME XXXX.\ '' ''
# Preprocessed tokens 821 : Good afternoon starshine ! How 's boytoy ? Does crave yet ? Ache fuck ? * sip cappuccino * I miss babe * teasing kiss *
# Preprocessed tokens 822 : On road cant txt
# Preprocessed tokens 823 : SMSSERVICES . yourinclusive text credit , pls goto www.comuk.net login= 3qxj9 unsubscribe STOP , extra charge . help 08702840625.COMUK . 220-CM2 9AE
# Preprocessed tokens 824 : 25p 4 alfie Moon 's Children need song ur mob . Tell ur m8s . Txt Tone charity 8007 Nokias Poly charity polys : zed 08701417012 profit 2 charity .
# Preprocessed tokens 825 : Have good evening ! Ttyl
# Preprocessed tokens 826 : Hmm .. Bits piece lol ... * sigh * ...
# Preprocessed tokens 827 : Hahaha .. use brain dear
# Preprocessed tokens 828 : Hey . You got mail ?
# Preprocessed tokens 829 : Sorry light turned green , I meant another friend wanted & lt ; # & gt ; worth may around
# Preprocessed tokens 830 : Thanks yesterday sir . You wonderful . Hope enjoyed burial . MojiBiola
# Preprocessed tokens 831 : U secret admirer . REVEAL think U R So special . Call 09065174042 . To opt Reply REVEAL STOP . 1.50 per msg recd . Cust care 07821230901
# Preprocessed tokens 832 : Hi mate RV u hav nice hol message 3 say hello coz havenåÕt sent u 1 age started driving stay road ! RVx
# Preprocessed tokens 833 : Dear Voucher Holder , To claim week offer , PC please go http : //www.e-tlp.co.uk/expressoffer Ts & Cs apply . To stop text , txt STOP 80062
# Preprocessed tokens 834 : Thank much . When skyped wit kz sura , didnt get pleasure company . Hope good . We 've given ultimatum oh ! We countin aburo . Enjoy ! This message sent day ago
# Preprocessed tokens 835 : Surely result offer : )
# Preprocessed tokens 836 : Good Morning Dear ........... Have great & amp ; successful day .
# Preprocessed tokens 837 : Do want 750 anytime network min 150 text NEW VIDEO phone five pound per week call 08002888812 reply delivery tomorrow
# Preprocessed tokens 838 : Sir , I late paying rent past month pay $ & lt ; # & gt ; charge . I felt would inconsiderate nag something give great cost 's didnt speak . I however recession wont able pay charge month hence askin well ahead month 's end . Can please help . Thanks
# Preprocessed tokens 839 : We tried contact offer New Video Phone 750 anytime network min HALF PRICE Rental camcorder call 08000930705 reply delivery Wed
# Preprocessed tokens 840 : Last chance 2 claim ur å£150 worth discount vouchers-Text YES 85023 ! SavaMob-member offer mobile T Cs 08717898035. å£3.00 Sub . 16 . Remove txt X STOP
# Preprocessed tokens 841 : I luv u soo much u donåÕt understand special u r 2 ring u 2morrow luv u xxx
# Preprocessed tokens 842 : Pls send comprehensive mail 'm paying , much .
# Preprocessed tokens 843 : Our Prashanthettan 's mother passed away last night . pray family .
# Preprocessed tokens 844 : Urgent ! call 09066350750 landline . Your complimentary 4 * Ibiza Holiday 10,000 cash await collection SAE T & Cs PO BOX 434 SK3 8WP 150 ppm 18+
# Preprocessed tokens 845 : K.k : ) going ?
# Preprocessed tokens 846 : Meanwhile shit suite : xavier decided give u & lt ; # & gt ; second warning samantha coming playing jay 's guitar impress shit . Also I n't think doug realizes I n't live anymore
# Preprocessed tokens 847 : My stomach thru much trauma I swear I ca n't eat . I better lose weight .
# Preprocessed tokens 848 : I office : ) whats matter .. msg now.i call break : ) .
# Preprocessed tokens 849 : Yeah 's barely enough room two u , x many fucking shoe . Sorry man , see later
# Preprocessed tokens 850 : Today 's Offer ! Claim ur å£150 worth discount voucher ! Text YES 85023 ! SavaMob , member offer mobile ! T Cs 08717898035. å£3.00 Sub . 16 . Unsub reply X
# Preprocessed tokens 851 : U reach orchard already ? U wan 2 go buy ticket first ?
# Preprocessed tokens 852 : I real , baby ! I want bring inner tigress ...
# Preprocessed tokens 853 : No da run activate full version da .
# Preprocessed tokens 854 : \AH POOR BABY ! HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE OF WORK HEY GO CAREFUL SPK 2 U SN LOTS OF LOVEJEN XXX.\ '' ''
# Preprocessed tokens 855 : Stop story . I 've told 've returned 's saying order .
# Preprocessed tokens 856 : Talk sexy ! ! Make new friend fall love world discreet text dating service . Just text VIP 83110 see could meet .
# Preprocessed tokens 857 : Going take babe ?
# Preprocessed tokens 858 : Hai ana tomarrow coming morning . & lt ; DECIMAL & gt ; ill sathy go RTO office . Reply came home .
# Preprocessed tokens 859 : Spoons okay ?
# Preprocessed tokens 860 : Did say somebody named tampa
# Preprocessed tokens 861 : In work . Going min .
# Preprocessed tokens 862 : Your brother genius
# Preprocessed tokens 863 : Sorry , I guess whenever I get hold connection , maybe hour two ? I 'll text
# Preprocessed tokens 864 : Did u find time bus coz need sort stuff .
# Preprocessed tokens 865 : Dude ive seeing lotta corvette lately
# Preprocessed tokens 866 : Congratulations ur awarded either yr supply CDs Virgin Records Mystery Gift GUARANTEED Call 09061104283 Ts & Cs www.smsco.net å£1.50pm approx 3mins
# Preprocessed tokens 867 : Same , I consider wall bunker shit important I never play peaceful I guess place high enough n't matter
# Preprocessed tokens 868 : PRIVATE ! Your 2003 Account Statement 07808 XXXXXX show 800 un-redeemed S. I. M. point . Call 08719899217 Identifier Code : 41685 Expires 07/11/04
# Preprocessed tokens 869 : Hello . We need posh bird chap user trial prod champneys . Can put ? I need address dob asap . Ta r
# Preprocessed tokens 870 : What U want Xmas ? How 100 free text message & new video phone half price line rental ? Call free 0800 0721072 find !
# Preprocessed tokens 871 : Well officially philosophical hole , u wan na call home ready saved !
# Preprocessed tokens 872 : Its going good ... problem .. still need little experience understand american customer voice ...
# Preprocessed tokens 873 : I 'll text I drop x
# Preprocessed tokens 874 : Ugh long day . I 'm exhausted . Just want cuddle take nap
# Preprocessed tokens 875 : Talk With Yourself Atleast Once In A Day ... ! ! ! Otherwise You Will Miss Your Best FRIEND In This WORLD ... ! ! ! -Shakespeare- SHESIL & lt ; # & gt ;
# Preprocessed tokens 876 : Shop till u Drop , IS IT YOU , either 10K , 5K , å£500 Cash å£100 Travel voucher , Call , 09064011000 . NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary
# Preprocessed tokens 877 : Are castor ? You need see something
# Preprocessed tokens 878 : Sunshine Quiz Wkly Q ! Win top Sony DVD player u know country Liverpool played mid week ? Txt ansr 82277. å£1.50 SP : Tyrone
# Preprocessed tokens 879 : U secret admirer looking 2 make contact U-find R * reveal think UR special-call 09058094565
# Preprocessed tokens 880 : U Secret Admirer looking 2 make contact U-find R * reveal think UR special-call 09065171142-stopsms-08
# Preprocessed tokens 881 : Reminder : You downloaded content already paid . Goto http : //doit . mymoby . tv/ collect content .
# Preprocessed tokens 882 : see , knew giving break time woul lead always wanting miss curfew . I gon na gibe 'til one , MIDNIGHT movie gon na get til 2 . You need come home . You need getsleep , anything , need b studdying ear training .
# Preprocessed tokens 883 : I love give massage . I use lot baby oil ... What fave position ?
# Preprocessed tokens 884 : Dude go sup
# Preprocessed tokens 885 : Yoyyooo u know change permission drive mac . My usb flash drive
# Preprocessed tokens 886 : Gibbs unsold.mike hussey
# Preprocessed tokens 887 : I like talk pa able . I dont know .
# Preprocessed tokens 888 : Y dun cut short leh . U dun like ah ? She failed . She 's quite sad .
# Preprocessed tokens 889 : You unbelievable faglord
# Preprocessed tokens 890 : Wife.how knew time murder exactly
# Preprocessed tokens 891 : Why ask princess ?
# Preprocessed tokens 892 : I great princess ! What thinking ? : )
# Preprocessed tokens 893 : Nutter . Cutter . Ctter . Cttergg . Cttargg . Ctargg . Ctagg . ie
# Preprocessed tokens 894 : It 's ok noe u 're busy 'm really bored msg u. I oso dunno wat colour choose 4 one .
# Preprocessed tokens 895 : Does n't g class early tomorrow thus n't trying smoke & lt ; # & gt ;
# Preprocessed tokens 896 : Superb Thought- \Be grateful u dont everything u want . That mean u still opportunity happier tomorrow u today.\ '' : - ) ''
# Preprocessed tokens 897 : Hope good week . Just checking
# Preprocessed tokens 898 : I 'm used . I hope agent n't drop since 've booked thing year . This whole boston , nyc experiment .
# Preprocessed tokens 899 : Thursday night ? Yeah , sure thing , 'll work
# Preprocessed tokens 900 : Your free ringtone waiting collected . Simply text password \MIX\ '' 85069 verify . Get Usher Britney . FML
# Preprocessed tokens 901 : Probably money worry . Things coming due several outstanding invoice work two three month ago .
# Preprocessed tokens 902 : How possible teach . And .
# Preprocessed tokens 903 : I wonder phone battery went dead ? I tell , I love babe
# Preprocessed tokens 904 : Lovely smell bus ai n't tobacco ...
# Preprocessed tokens 905 : We 're getting worried , derek taylor already assumed worst
# Preprocessed tokens 906 : Hey 's charles sorry late reply .
# Preprocessed tokens 907 : lastest Stereophonics , Marley , Dizzee Racal , Libertines The Strokes ! Win Nookii game Flirt ! ! Click TheMob WAP Bookmark text WAP 82468
# Preprocessed tokens 908 : I.ll give . Plus said grinule greet whenever speak
# Preprocessed tokens 909 : WHITE FUDGE OREOS ARE IN STORES
# Preprocessed tokens 910 : January Male Sale ! Hot Gay chat cheaper , call 08709222922 . National rate 1.5p/min cheap 7.8p/min peak ! To stop text call 08712460324 ( 10p/min )
# Preprocessed tokens 911 : My love ! How come took long leave Zaher 's ? I got word ym happy see sad left . I miss
# Preprocessed tokens 912 : I sorry hurt .
# Preprocessed tokens 913 : Ca n't . I feel nauseous . I 'm pissed . I n't eat sweet week cause today I planning pig . I dieting week . And I 'm hungry : /
# Preprocessed tokens 914 : Ok lor early . Me still project meeting .
# Preprocessed tokens 915 : Call da , waiting call .
# Preprocessed tokens 916 : I could ask carlos could get anybody else chip
# Preprocessed tokens 917 : Was actually send reminder today . Have wonderful weekend
# Preprocessed tokens 918 : When people see msg , They think Iam addicted msging ... They wrong , Bcoz They don\'t know Iam addicted sweet Friends .. ! ! BSLVYL
# Preprocessed tokens 919 : Hey gave photo registered driving ah ? Tmr wan na meet yck ?
# Preprocessed tokens 920 : Dont talk ever ok word .
# Preprocessed tokens 921 : When u wana see
# Preprocessed tokens 922 : On way school . Can pls send ashley 's number
# Preprocessed tokens 923 : It shall fine . I avalarr . Will hollalater
# Preprocessed tokens 924 : She went attend another two round today .. still did't reach home ..
# Preprocessed tokens 925 : Actually deleted old website .. blogging magicalsongs.blogspot.com
# Preprocessed tokens 926 : K , wait chikku .. il send aftr & lt ; # & gt ; min
# Preprocessed tokens 927 : But I 'm diet . And I ate 1 many slice pizza yesterday . Ugh I 'm ALWAYS diet .
# Preprocessed tokens 928 : K : ) give kvb acc detail : )
# Preprocessed tokens 929 : Oh come ah ?
# Preprocessed tokens 930 : money ! ! ! r lucky winner ! 2 claim prize text money 2 88600 å£1million give away ! ppt150x3+normal text rate box403 w1t1jy
# Preprocessed tokens 931 : I 'm really sorry wo n't b able 2 friday.hope u find alternative.hope yr term 's going ok : - )
# Preprocessed tokens 932 : Congratulations ore mo owo wa . Enjoy wish many happy moment fro wherever go
# Preprocessed tokens 933 : So samus shoulder yet
# Preprocessed tokens 934 : What time think 'll ? Need know I near campus
# Preprocessed tokens 935 : Dear Matthew please call 09063440451 landline , complimentary 4 * Lux Tenerife holiday å£1000 CASH await collection . ppm150 SAE T & Cs Box334 SK38XH .
# Preprocessed tokens 936 : Then dun wear jean lor ...
# Preprocessed tokens 937 : Since , side , fever , vomitin .
# Preprocessed tokens 938 : K : ) k.are college ?
# Preprocessed tokens 939 : Urgent ! call 09061749602 Landline . Your complimentary 4 * Tenerife Holiday å£10,000 cash await collection SAE T & Cs BOX 528 HP20 1YF 150ppm 18+
# Preprocessed tokens 940 : Better . Made Friday stuffed like pig yesterday . Now I feel bleh . But least writhing pain kind bleh .
# Preprocessed tokens 941 : No sell 'll ton coin . Then sell coin someone thru paypal . Voila ! Money back life pocket : )
# Preprocessed tokens 942 : Theyre lot place . Only hospital medical place safe .
# Preprocessed tokens 943 : How getting touch folk waiting company ? Just txt back NAME AGE opt ! Enjoy community ( 150p/SMS )
# Preprocessed tokens 944 : And also I 've sorta blown couple time recently id rather text blue looking weed
# Preprocessed tokens 945 : I sent score sophas secondary application school . I think thinking applying , research cost also . Contact joke ogunrinde , school one le expensive one
# Preprocessed tokens 946 : I cant wait see ! How photo useful ? : )
# Preprocessed tokens 947 : Ur cash-balance currently 500 pound - maximize ur cash-in send GO 86688 150p/msg . CC : 08718720201 PO BOX 114/14 TCR/W1
# Preprocessed tokens 948 : Hey booked kb sat already ... lesson going ah ? Keep sat night free need meet confirm lodging
# Preprocessed tokens 949 : Chk ur belovd m dict
# Preprocessed tokens 950 : Is time want come ?
# Preprocessed tokens 951 : Awesome , lem know whenever 're around
# Preprocessed tokens 952 : Shb b ok lor ... Thanx ...
# Preprocessed tokens 953 : Beautiful Truth Gravity .. Read carefully : \Our heart feel light someone .. But feel heavy someone leaf .. \ '' GOOD NIGHT ''
# Preprocessed tokens 954 : Also remember get dobby 's bowl car
# Preprocessed tokens 955 : Filthy story GIRLS waiting
# Preprocessed tokens 956 : Sorry c ur msg ... Yar lor poor thing ... But 4 one night ... Tmr u 'll brand new room 2 sleep ...
# Preprocessed tokens 957 : Love n't decision , 's feeling . If could decide love , , life would much simpler , le magical
# Preprocessed tokens 958 : Welp apparently retired
# Preprocessed tokens 959 : My sort code acc . The bank natwest . Can reply confirm 've sent right person !
# Preprocessed tokens 960 : Where @
# Preprocessed tokens 961 : U sure u ca n't take sick time ?
# Preprocessed tokens 962 : URGENT ! We trying contact U. Todays draw show å£800 prize GUARANTEED . Call 09050001808 land line . Claim M95 . Valid12hrs
# Preprocessed tokens 963 : Watching cartoon , listening music & amp ; eve go temple & amp ; church .. What u ?
# Preprocessed tokens 964 : Yo chad gymnastics class wan na take ? The site say Christians class full ..
# Preprocessed tokens 965 : Are much buzy
# Preprocessed tokens 966 : Or better still catch let ask sell & lt ; # & gt ; .
# Preprocessed tokens 967 : I sure night menu . . . I know noon menu
# Preprocessed tokens 968 : What u want come back ? .a beautiful necklace token heart you.thats give ONLY MY WIFE OF MY LIKING.BE THAT AND SEE .. NO ONE give that.dont call me.i wait till come .
# Preprocessed tokens 969 : Are willing go aptitude class .
# Preprocessed tokens 970 : It wont b 2.15 trying 2 sort house , ok ?
# Preprocessed tokens 971 : Yar lor wan 2 go c horse racing today mah , eat earlier lor . I ate chicken rice . U ?
# Preprocessed tokens 972 : Haha awesome , omw back
# Preprocessed tokens 973 : Yup thk e shop close lor .
# Preprocessed tokens 974 : account number ?
# Preprocessed tokens 975 : Eh u send wrongly lar ...
# Preprocessed tokens 976 : Hey I ad crap nite borin without ya 2 boggy u boring biatch ! Thanx u wait til nxt time il ave ya
# Preprocessed tokens 977 : Ok shall talk
# Preprocessed tokens 978 : Dont hesitate . You know second time weakness like . So keep notebook eat day anything changed day sure nothing
# Preprocessed tokens 979 : Hey pay . With salary de . Only & lt ; # & gt ; .
# Preprocessed tokens 980 : Another month . I need chocolate weed alcohol .
# Preprocessed tokens 981 : If started searching get job days.he great potential talent .
# Preprocessed tokens 982 : Reckon need town eightish walk * carpark .
# Preprocessed tokens 983 : Congrats ! 2 mobile 3G Videophones R . call 09063458130 ! videochat wid mate , play java game , Dload polyPH music , noline rentl .
# Preprocessed tokens 984 : LOOK AT THE FUCKIN TIME . WHAT THE FUCK YOU THINK IS UP
# Preprocessed tokens 985 : Yo guess I dropped
# Preprocessed tokens 986 : Carlos say 'll mu & lt ; # & gt ; minute
# Preprocessed tokens 987 : I 'm office . I call & lt ; # & gt ; min : )
# Preprocessed tokens 988 : Geeee ... I miss already , know ? Your I think . Fuck , I ca n't wait till next year together ... * loving kiss *
# Preprocessed tokens 989 : Yun ah.the ubi one say Ì_ wan call tomorrow.call 67441233 look irene.ere got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph 1st 5wkg days.Ì¬n
# Preprocessed tokens 990 : Ugh . Got ta drive back sd la . My butt sore .
# Preprocessed tokens 991 : 26th OF JULY
# Preprocessed tokens 992 : Hi im relaxing time ever ! get 7am every day ! party good night ? I get home tomorrow 5ish .
# Preprocessed tokens 993 : Up Ì_ ... ÌÏ wan come come lor ... But din c stripe skirt ...
# Preprocessed tokens 994 : The Xmas story peace .. The Xmas msg love .. The Xmas miracle jesus .. Hav blessed month ahead & amp ; wish U Merry Xmas ...
# Preprocessed tokens 995 : I ca n't , I n't number !
# Preprocessed tokens 996 : Change ... It 's e one next escalator ...
# Preprocessed tokens 997 : Yetunde 'm class run water make ok. Pls .
# Preprocessed tokens 998 : Not lot happened . Feels quiet . Beth aunt charlie working lot . Just helen mo . How ?
# Preprocessed tokens 999 : Then Ì_ wait 4 bus stop aft ur lect lar . If dun c Ì_ go get car come back n pick Ì_ .
# Preprocessed tokens 1000 : Aight , thanks comin
# Preprocessed tokens 1001 : No .. heard abt tat ..
# Preprocessed tokens 1002 : Please call customer service representative FREEPHONE 0808 145 4742 9am-11pm WON guaranteed å£1000 cash å£5000 prize !
# Preprocessed tokens 1003 : Yes .. really great .. bhaji told kallis best cricketer sachin world : ) .very tough get .
# Preprocessed tokens 1004 : & lt ; # & gt ; I think ? Should say syllabus
# Preprocessed tokens 1005 : Umma . Did say anything
# Preprocessed tokens 1006 : Give sec think think
# Preprocessed tokens 1007 : Panasonic & BluetoothHdset FREE . Nokia FREE . Motorola FREE & DoubleMins & DoubleTxt Orange contract . Call MobileUpd8 08000839402 call 2optout
# Preprocessed tokens 1008 : I n't quite know . I still ca n't get hold anyone . I cud pick bout 7.30pm see 're pub ?
# Preprocessed tokens 1009 : Poyyarikatur , kolathupalayam , unjalur post , erode dis , & lt ; # & gt ; .
# Preprocessed tokens 1010 : Dear Hero , leaving qatar tonite apt opportunity.pls keep touch & lt ; EMAIL & gt ; , kerala
# Preprocessed tokens 1011 : Lol I would mom would fit tell whole family crazy terrible I
# Preprocessed tokens 1012 : I got home babe , still awake ?
# Preprocessed tokens 1013 : I dunno close oredi ... ÌÏ v fan ...
# Preprocessed tokens 1014 : Just buy pizza . Meat lover supreme . U get pick .
# Preprocessed tokens 1015 : Ya , told .. asking wats matter ?
# Preprocessed tokens 1016 : Dear , regret cudnt pick call.drove frm ctla cochin home.left mobile car .. ente style ishtamayoo ? happy bakrid !
# Preprocessed tokens 1017 : FREE 1st week ! No1 Nokia tone 4 ur mob every week txt NOKIA 8007 Get txting tell ur mate www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+
# Preprocessed tokens 1018 : Shall send exe mail id .
# Preprocessed tokens 1019 : Nope watching tv home ... Not going . V bored ...
# Preprocessed tokens 1020 : Don know .. wait check .
# Preprocessed tokens 1021 : Good afternoon glorious anniversary day , sweet J ! ! I hope find happy content , Prey . I think send teasing kiss across sea coaxing image fond souveniers ... You Cougar-Pen
# Preprocessed tokens 1022 : Guess ! Somebody know secretly fancy ! Wan na find ? Give u call 09065394514 From Landline DATEBox1282EssexCM61XN 150p/min 18
# Preprocessed tokens 1023 : We still tonight ?
# Preprocessed tokens 1024 : May call You later Pls
# Preprocessed tokens 1025 : Has n't pattern recently crap weekend ?
# Preprocessed tokens 1026 : I sore throat . It 's scratch I talk
# Preprocessed tokens 1027 : Yes da . Any plm ur office
# Preprocessed tokens 1028 : Are around still asleep ? : V
# Preprocessed tokens 1029 : Lol forgot eh ? Yes , I 'll bring babe
# Preprocessed tokens 1030 : Its good , 'll find way
# Preprocessed tokens 1031 : Can use foreign stamp country . Good lecture .
# Preprocessed tokens 1032 : Yup bathe liao ...
# Preprocessed tokens 1033 : HAPPY NEW YEAR MY NO.1 MAN
# Preprocessed tokens 1034 : OH MR SHEFFIELD ! You wan na play THAT game , okay . You 're bos I 'm nanny . You give raise I 'll give YOU one ! !
# Preprocessed tokens 1035 : ZOE IT JUST HIT ME 2 IM FUCKING SHITIN MYSELF IL DEFO TRY MY HARDEST 2 CUM 2MOROW LUV U MILLIONS LEKDOG
# Preprocessed tokens 1036 : Hello baby , get back mom 's ? Are setting computer ? Filling belly ? How go loverboy ? I miss already ... * sigh *
# Preprocessed tokens 1037 : No blanket sufficient , thx
# Preprocessed tokens 1038 : naughty little thought : 'its better flirt , flirt n flirt , rather loving someone n gettin hurt , hurt n hurt ... : - ) Gud nyt
# Preprocessed tokens 1039 : Edison rightly said , \A fool ask question wise man answer\ '' Now know u speechless ViVa .. GM
# Preprocessed tokens 1040 : They talking thats de . They wont .
# Preprocessed tokens 1041 : Today going college able atten class .
# Preprocessed tokens 1042 : I 'm class . Will holla later
# Preprocessed tokens 1043 : Easy ah ? sen got selected mean good ..
# Preprocessed tokens 1044 : Mmm thats better got roast ! iåÕd b better drink 2 ! Good indian ?
# Preprocessed tokens 1045 : We know someone know fancy . Call 09058097218 find . POBox 6 , LS15HB 150p
# Preprocessed tokens 1046 : Come round , 's .
# Preprocessed tokens 1047 : Do 1 thing ! Change sentence : \Because want 2 concentrate educational career im leaving .. \ '' ''
# Preprocessed tokens 1048 : 1000 's flirting NOW ! Txt GIRL BLOKE & ur NAME & AGE , eg GIRL ZOE 18 8007 join get chatting !
# Preprocessed tokens 1049 : I walked hour 2 c u ! doesnåÕt show I care wont u believe im serious ?
# Preprocessed tokens 1050 : 18 day Euro2004 kickoff ! U kept informed latest news result daily . Unsubscribe send GET EURO STOP 83222 .
# Preprocessed tokens 1051 : Are available soiree June 3rd ?
# Preprocessed tokens 1052 : Do u noe wat time e place dat sell 4d close ?
# Preprocessed tokens 1053 : I got another job ! The one hospital data analysis something , start monday ! Not sure thesis got finished
# Preprocessed tokens 1054 : Jay 's getting really impatient belligerent
# Preprocessed tokens 1055 : HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# Preprocessed tokens 1056 : I 'm work . Please call
# Preprocessed tokens 1057 : Then u drive lor .
# Preprocessed tokens 1058 : Ard 515 like dat . Y ?
# Preprocessed tokens 1059 : Tell 're female : V 're throwing ? We 're deciding get
# Preprocessed tokens 1060 : EASTENDERS TV Quiz . What FLOWER DOT compare ? D= VIOLET E= TULIP F= LILY txt D E F 84025 NOW 4 chance 2 WIN å£100 Cash WKENT/150P16+
# Preprocessed tokens 1061 : I 'm working technical support : ) voice process.networking field .
# Preprocessed tokens 1062 : I might come kerala 2 days.so prepared take leave finalise .dont plan travel visit.need finish urgent work .
# Preprocessed tokens 1063 : Ok. Not sure time tho sure get library class . Will try . See point ! Have good eve .
# Preprocessed tokens 1064 : We new local date area - Lots new people registered YOUR AREA . Reply DATE start ! 18 www.flirtparty.us REPLYS150
# Preprocessed tokens 1065 : That 's fine , I 'll bitch later
# Preprocessed tokens 1066 : No mum went 2 dentist .
# Preprocessed tokens 1067 : Once free call sir . I waiting .
# Preprocessed tokens 1068 : Meeting u work . . . Tel shall work tomorrow
# Preprocessed tokens 1069 : Someone U know asked dating service 2 contact ! Cant Guess ? CALL 09058091854 NOW revealed . PO BOX385 M6 6WU
# Preprocessed tokens 1070 : Jus finish bathing ...
# Preprocessed tokens 1071 : alright , I 'll make sure car back tonight
# Preprocessed tokens 1072 : URGENT ! We trying contact U. Todays draw show å£800 prize GUARANTEED . Call 09050003091 land line . Claim C52 . Valid12hrs
# Preprocessed tokens 1073 : Dear U 've invited XCHAT . This final attempt contact u ! Txt CHAT 86688
# Preprocessed tokens 1074 : Lul im gettin juicy gossip hospital . Two nurse talking fat gettin . And one think shes obese . Oyea .
# Preprocessed tokens 1075 : Aight ill get fb couple minute
# Preprocessed tokens 1076 : Oi . Ami parchi na . Kicchu kaaj korte iccha korche na . Phone ta tul na . Plz . Plz .
# Preprocessed tokens 1077 : Where download clear movie . Dvd copy .
# Preprocessed tokens 1078 : Yep , pretty sculpture
# Preprocessed tokens 1079 : Convey regard
# Preprocessed tokens 1080 : Me watching surya movie . . .after 6 pm vijay movie POKKIRI
# Preprocessed tokens 1081 : You tell happen dont behave like . Ok need say
# Preprocessed tokens 1082 : Can u get pic msg phone ?
# Preprocessed tokens 1083 : Send someone else : - )
# Preprocessed tokens 1084 : Wat make people dearer de happiness dat u feel u meet de pain u feel u miss dem ! ! !
# ...
# Preprocessed tokens 5389 : NOT MUCH NO FIGHTS . IT WAS A GOOD NITE ! !
# Preprocessed tokens 5390 : Ok.ok ok .. .. whats ur today plan
# Preprocessed tokens 5391 : Nt joking seriously told
# Preprocessed tokens 5392 : Watching ajith film ah ?
# Preprocessed tokens 5393 : Ooooooh I forgot tell u I get yoville phone
# Preprocessed tokens 5394 : All done , handed . Do n't know mega shop asda count celebration thats 'm !
# Preprocessed tokens 5395 : I dont know exactly could ask chechi .
# Preprocessed tokens 5396 : Dunno lei shd b driving lor co go sch 1 hr oni .
# Preprocessed tokens 5397 : As want custom officer discount oh .
# Preprocessed tokens 5398 : That 's necessarily respectful
# Preprocessed tokens 5399 : Hi . Hope good day . Have better night .
# Preprocessed tokens 5400 : And 's apparently bffs carly quick
# Preprocessed tokens 5401 : HARD BUT TRUE : How much show & amp ; express love someone .... much hurt leave get seperated ... ! ö´Ó_ ? ? Û¬ud evening ...
# Preprocessed tokens 5402 : Babes I think I got ur brolly I left English wil bring 2mrw 4 u luv Franxx
# Preprocessed tokens 5403 : Hi babe thanks coming even though didnt go well ! wanted bed ! Hope see soon love kiss xxx
# Preprocessed tokens 5404 : So gd got free ice cream ... I oso wan ...
# Preprocessed tokens 5405 : Pls give prometazine syrup . 5mls & lt ; # & gt ; min later feed .
# Preprocessed tokens 5406 : So many day since ?
# Preprocessed tokens 5407 : Dear angry busy dear
# Preprocessed tokens 5408 : Yup msg : tat yijue ? Then tot 's group mate co meeting today mah ... I 'm askin Ì_ leaving earlier wat mah co mayb Ì_ haf walk v far ...
# Preprocessed tokens 5409 : ... Are pub ?
# Preprocessed tokens 5410 : There first time everything : )
# Preprocessed tokens 5411 : Daddy , shu shu looking 4 u ... U wan 2 tell u 're singapore wat ?
# Preprocessed tokens 5412 : I ask u meeting da ge tmr nite ...
# Preprocessed tokens 5413 : Gr8 . So handle victoria island traffic . Plus 's album due
# Preprocessed tokens 5414 : Nite nite pocay wocay luv u n e thing 4eva I promise ring u 2morrowxxxx
# Preprocessed tokens 5415 : East coast
# Preprocessed tokens 5416 : You get chicken broth want ramen unless 's I n't know
# Preprocessed tokens 5417 : My slave ! I want take 2 3 picture today bright light cell phone ! Bright light !
# Preprocessed tokens 5418 : Nope . I forgot . Will show next week
# Preprocessed tokens 5419 : So really . What . How 's master . And .
# Preprocessed tokens 5420 : I 'm bruce & amp ; fowler I 'm mom 's car I ca n't park ( long story )
# Preprocessed tokens 5421 : I dont know oh . Hopefully month .
# Preprocessed tokens 5422 : Hi elaine , today 's meeting confirmed ?
# Preprocessed tokens 5423 : Ok k .. sry knw 2 siva .. tat askd ..
# Preprocessed tokens 5424 : Sorry , I 'll call later
# Preprocessed tokens 5425 : U horrible gal ... U knew dat going wif yest n u still come n ask ...
# Preprocessed tokens 5426 : Otherwise part time job na-tuition ..
# Preprocessed tokens 5427 : Oh yeah ! And diet flew window
# Preprocessed tokens 5428 : Santa Calling ! Would little one like call Santa Xmas eve ? Call 09058094583 book time .
# Preprocessed tokens 5429 : You didnt complete gist oh .
# Preprocessed tokens 5430 : Er yeah , b 15:26 , sorry ! Just tell pub/cafe sit come wen u
# Preprocessed tokens 5431 : If make time tonight whenever 's cool , text whenever 're around
# Preprocessed tokens 5432 : If I I n't paying attention
# Preprocessed tokens 5433 : Thanx lot 4 ur help !
# Preprocessed tokens 5434 : You 're gon na way specific
# Preprocessed tokens 5435 : Jesus armand really trying tell everybody find
# Preprocessed tokens 5436 : I 'm wif buying tix lar ...
# Preprocessed tokens 5437 : Mode men left .
# Preprocessed tokens 5438 : Am slow using biola 's fne
# Preprocessed tokens 5439 : \What youdoing later ? Sar xxx\ '' ''
# Preprocessed tokens 5440 : Hey 've booked 2 lesson sun liao ...
# Preprocessed tokens 5441 : Thank . generally date brothas ?
# Preprocessed tokens 5442 : By way , make sure u get train worc foregate street shrub hill . Have fun night x
# Preprocessed tokens 5443 : I thought 'd get watch , co thats kind thing u get4an18th . And love much !
# Preprocessed tokens 5444 : You guaranteed 32000 award maybe even å£1000 cash claim ur award call free 0800 ..... ( 18+ ) . Its legitimat efreefone number wat u think ? ? ?
# Preprocessed tokens 5445 : Good morning . At repair shop -- ONLY reason 'm hour .
# Preprocessed tokens 5446 : And 's fine , I got enough bud last night least
# Preprocessed tokens 5447 : I back . Good journey ! Let know need receipt . Shall tell like pendent ?
# Preprocessed tokens 5448 : So take away money worry
# Preprocessed tokens 5449 : aight pick , open tonight ?
# Preprocessed tokens 5450 : Latest News ! Police station toilet stolen , cop nothing go !
# Preprocessed tokens 5451 : Sac need carry : )
# Preprocessed tokens 5452 : Just sing HU . I think also important find someone female know place well preferably citizen also smart help navigate . Even thing like choosing phone plan require guidance . When doubt ask especially girl .
# Preprocessed tokens 5453 : What ? ? ? ? Hello wats talk email address ?
# Preprocessed tokens 5454 : Except there chick huge boob .
# Preprocessed tokens 5455 : Im wondering right ?
# Preprocessed tokens 5456 : Wishing beautiful day . Each moment revealing even thing keep smiling . Do enjoy .
# Preprocessed tokens 5457 : \For sparkling shopping break 45 per person ; call 0121 2025050 visit www.shortbreaks.org.uk\ '' ''
# Preprocessed tokens 5458 : Arun u transfr amt
# Preprocessed tokens 5459 : Sorry , I 'll call later
# Preprocessed tokens 5460 : If hear loud scream & lt ; # & gt ; minute cause Gyno shoving thing n't belong : /
# Preprocessed tokens 5461 : December ! Had mobile 11mths+ ? You entitled update latest colour camera mobile Free ! Call The Mobile Update Co FREE 08002986906
# Preprocessed tokens 5462 : Ok thk got . Then u wan 2 come wat ?
# Preprocessed tokens 5463 : Txt : CALL No : 86888 & claim reward 3 hour talk time use phone ! Subscribe6GBP/mnth inc 3hrs 16 stop ? txtStop www.gamb.tv
# Preprocessed tokens 5464 : U GOIN OUT 2NITE ?
# Preprocessed tokens 5465 : I treasure every moment spend together ...
# Preprocessed tokens 5466 : Shall I bring u bottle wine keep u amused ? Only joking ! IÛ÷ll bring one anyway
# Preprocessed tokens 5467 : http//tms . widelive.com/index . wml ? id=820554ad0a1705572711 & first=trueåÁC C RingtoneåÁ
# Preprocessed tokens 5468 : Get garden ready summer FREE selection summer bulb seed worth å£33:50 The Scotsman Saturday . To stop go2 notxt.co.uk
# Preprocessed tokens 5469 : URGENT ! Last weekend 's draw show å£1000 cash Spanish holiday ! CALL NOW 09050000332 claim . T & C : RSTM , SW7 3SS . 150ppm
# Preprocessed tokens 5470 : Ok lor .
# Preprocessed tokens 5471 : I thought slide enough .
# Preprocessed tokens 5472 : Yup
# Preprocessed tokens 5473 : Well obviously people cool college life went home ; _ ;
# Preprocessed tokens 5474 : Ok lor Ì_ reaching message .
# Preprocessed tokens 5475 : Where 's mummy 's boy ? Is good bad ? Is positive negative ? Why mummy made wait ? Hmmmm ?
# Preprocessed tokens 5476 : Dhoni luck win big title.so win : )
# Preprocessed tokens 5477 : Yes princess ! I want please every night . Your wish command ...
# Preprocessed tokens 5478 : What Today-sunday .. sunday holiday .. work ..
# Preprocessed tokens 5479 : No probably & lt ; # & gt ; % .
# Preprocessed tokens 5480 : Really hope work doesnt get stressful . Have gr8 day .
# Preprocessed tokens 5481 : Have seen 's back Holby ? !
# Preprocessed tokens 5482 : Shall call dear food
# Preprocessed tokens 5483 : URGENT We trying contact Last weekend draw show u å£1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm
# Preprocessed tokens 5484 : So li hai ... Me bored da lecturer repeating last week stuff waste time ...
# Preprocessed tokens 5485 : , , picking various point | going 2 yeovil | motor project 4 3 hour | u take home . || 12 2 5.30 max . || Very easy
# Preprocessed tokens 5486 : Also fuck family going rhode island wherever fuck leaving alone week I new bong & gt ; : (
# Preprocessed tokens 5487 : Ofcourse I also upload song
# Preprocessed tokens 5488 : 2p per min call Germany 08448350055 BT line . Just 2p per min . Check PlanetTalkInstant.com info & T 's & C 's . Text stop opt
# Preprocessed tokens 5489 : K. I sent
# Preprocessed tokens 5490 : Oh thanks lot .. already bought 2 egg ..
# Preprocessed tokens 5491 : K. I sent
# Preprocessed tokens 5492 : U studying sch going home ? Anyway 'll b going 2 sch later .
# Preprocessed tokens 5493 : Marvel Mobile Play official Ultimate Spider-man game ( å£4.50 ) ur mobile right . Text SPIDER 83338 game & send u FREE 8Ball wallpaper
# Preprocessed tokens 5494 : I think rule tamilnadu .. tough people .
# Preprocessed tokens 5495 : Cool , shall go see , go tip anyway . Are home , got something drop later ? So let go town tonight ! Maybe mum take u .
# Preprocessed tokens 5496 : Good afternoon , love ... How go day ? How sleep ? I hope well , boytoy ... I think ...
# Preprocessed tokens 5497 : Yes ... I trust u buy new stuff ASAP I try
# Preprocessed tokens 5498 : SMS SERVICES . inclusive text credit , pls goto www.comuk.net login= 3qxj9 unsubscribe STOP , extra charge . help 08702840625.COMUK . 220-CM2 9AE
# Preprocessed tokens 5499 : Why I wake & gt ; : (
# Preprocessed tokens 5500 : Now get step 2 outta way . Congrats .
# Preprocessed tokens 5501 : Love one law ; Make happy person love . In way friendship one law ; Never make ur friend feel alone alive .... Gud night
# Preprocessed tokens 5502 : PRIVATE ! Your 2003 Account Statement 07808247860 show 800 un-redeemed S. I. M. point . Call 08719899229 Identifier Code : 40411 Expires 06/11/04
# Preprocessed tokens 5503 : Apo mokka player
# Preprocessed tokens 5504 : Perhaps * much easy give account identification , tomorrow UNI
# Preprocessed tokens 5505 : Wait . I msg & lt ; # & gt ; min .
# Preprocessed tokens 5506 : What told tell . Stupid hear wont tell anything . You dad called brother spoken . Not .
# Preprocessed tokens 5507 : God 's love limit . God 's grace measure . God 's power boundary . May u God 's endless blessing always ur life ... ! ! Gud ni8
# Preprocessed tokens 5508 : I want inside every night ...
# Preprocessed tokens 5509 : Machan go gym tomorrow , wil come late goodnight .
# Preprocessed tokens 5510 : Lol mad first woke gave .
# Preprocessed tokens 5511 : I went project centre
# Preprocessed tokens 5512 : ItÛ÷s reassuring , crazy world .
# Preprocessed tokens 5513 : Just making dinner , ?
# Preprocessed tokens 5514 : Yes . Please leave & lt ; # & gt ; . So & lt ; # & gt ; leave
# Preprocessed tokens 5515 : Oh ... Okie lor ... We go sat ...
# Preprocessed tokens 5516 : You great role model . You giving much really wish day miracle God reason everything must say wish knew dont . I 've looked since young still . Have great day .
# Preprocessed tokens 5517 : Ya , 'm referin mei 's ex wat ... No ah , waitin 4 u treat , somebody shld b rich liao ... So gd , den u dun work frm tmr onwards ...
# Preprocessed tokens 5518 : Miles smile r made frm letter u know difference .. ? smile ur face keep happy even though I mile away u .. : - ) keep smiling .. Good nyt
# Preprocessed tokens 5519 : By way , 've put skip right outside front house see house . Just pull .
# Preprocessed tokens 5520 : Can pls send company name . In saibaba colany
# Preprocessed tokens 5521 : No . I dont want hear anything
# Preprocessed tokens 5522 : You big chic . Common . Declare
# Preprocessed tokens 5523 : Thats cool . I want please ...
# Preprocessed tokens 5524 : Going join tomorrow .
# Preprocessed tokens 5525 : You awarded SiPix Digital Camera ! call 09061221061 landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p på£3.99
# Preprocessed tokens 5526 : I want tell bad I feel basically time I text lately I need drug
# Preprocessed tokens 5527 : PRIVATE ! Your 2003 Account Statement show 800 un-redeemed S.I.M . point . Call 08718738001 Identifier Code : 49557 Expires 26/11/04
# Preprocessed tokens 5528 : Total disappointment , I texted craziest shit got : (
# Preprocessed tokens 5529 : Its effect irritation . Just ignore
# Preprocessed tokens 5530 : What one .
# Preprocessed tokens 5531 : I think tantrum 's finished yeah I 'll point
# Preprocessed tokens 5532 : Compliments . Was away system . How side .
# Preprocessed tokens 5533 : happened adventuring
# Preprocessed tokens 5534 : Hey chief , give bell get . Need talk royal visit 1st june .
# Preprocessed tokens 5535 : Ok another number
# Preprocessed tokens 5536 : I know thinkin malaria . But relax , child cant handle malaria . She would worse gastroenteritis . If take enough replace loss temp reduce . And give malaria med vomit . Its self limiting illness mean day completely stop
# Preprocessed tokens 5537 : Aiyah ok wat long got improve already wat ...
# Preprocessed tokens 5538 : Want explicit SEX 30 sec ? Ring 02073162414 ! Costs 20p/min Gsex POBOX 2667 WC1N 3XX
# Preprocessed tokens 5539 : I ca n't believe attached I seeing every day . I know best get babe . I go teach class midnight
# Preprocessed tokens 5540 : Just sleeping .. surfing
# Preprocessed tokens 5541 : ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE MINS . INDIA CUST SERVs SED YES . L8ER GOT MEGA BILL . 3 DONT GIV A SHIT . BAILIFF DUE IN DAYS . I O å£250 3 WANT å£800
# Preprocessed tokens 5542 : Yeah 's jus rite ...
# Preprocessed tokens 5543 : Armand say get as epsilon
# Preprocessed tokens 5544 : U still havent got urself jacket ah ?
# Preprocessed tokens 5545 : I 'm taking derek & amp ; taylor walmart , I 'm back time 're done leave mouse desk I 'll text priscilla 's ready
# Preprocessed tokens 5546 : Hi durban still number
# Preprocessed tokens 5547 : Ic . There lotta childporn car .
# Preprocessed tokens 5548 : Had contract mobile 11 Mnths ? Latest Motorola , Nokia etc . FREE ! Double Mins & Text Orange tariff . TEXT YES callback , remove record .
# Preprocessed tokens 5549 : No , I trying weekend ; V
# Preprocessed tokens 5550 : You know , wot people wear . T shirt , jumper , hat , belt , know . We r Cribbs
# Preprocessed tokens 5551 : Cool , time think get ?
# Preprocessed tokens 5552 : Wen get spiritual deep . That 's great
# Preprocessed tokens 5553 : Have safe trip Nigeria . Wish happiness soon company share moment
# Preprocessed tokens 5554 : Hahaha .. use brain dear
# Preprocessed tokens 5555 : Well keep mind I 've got enough gas one round trip barring sudden influx cash
# Preprocessed tokens 5556 : Yeh . Indians nice . Tho kane bit . We shud go 4 drink sometime soon . Mite hav 2 go 2 da work 4 laugh soon . Love Pete x x
# Preprocessed tokens 5557 : Yes . So 's u texted . Pshew ... missing much
# Preprocessed tokens 5558 : No . I meant calculation . That & lt ; # & gt ; unit & lt ; # & gt ; . This school really expensive . Have started practicing accent . Because important . And decided 4years dental school 'll nmde exam .
# Preprocessed tokens 5559 : Sorry , I 'll call later
# Preprocessed tokens 5560 : n't next & lt ; # & gt ; hour imma flip shit
# Preprocessed tokens 5561 : Anything lor . Juz u lor .
# Preprocessed tokens 5562 : Get dump heap . My mom decided come lowes . BORING .
# Preprocessed tokens 5563 : Ok lor ... Sony ericsson salesman ... I ask shuhui say quite gd 2 use considering ...
# Preprocessed tokens 5564 : Ard 6 like dat lor .
# Preprocessed tokens 5565 : Why n't wait 'til least wednesday see get .
# Preprocessed tokens 5566 : Huh lei ...
# Preprocessed tokens 5567 : REMINDER FROM O2 : To get 2.50 pound free call credit detail great offer pls reply 2 text valid name , house postcode
# Preprocessed tokens 5568 : This 2nd time tried 2 contact u. U å£750 Pound prize . 2 claim easy , call 087187272008 NOW1 ! Only 10p per minute . BT-national-rate .
# Preprocessed tokens 5569 : Will Ì_ b going esplanade fr home ?
# Preprocessed tokens 5570 : Pity , * mood . So ... suggestion ?
# Preprocessed tokens 5571 : The guy bitching I acted like 'd interested buying something else next week gave u free
# Preprocessed tokens 5572 : Rofl . Its true name

# %% [markdown]
# # **Spilting Into Train & Test**

# %%
X_train, X_test, y_train, y_test = train_test_split(preprocessed_data, dataset.Y, test_size=0.2)

# %% [markdown]
# # **Text Classification Using Naive Bayes**

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X_train_features = vectorizer.fit_transform(X_train)
X_test_features = vectorizer.transform(X_test)
clf = MultinomialNB()
clf.fit(X_train_features, y_train)

y_pred = clf.predict(X_test_features)

# %% [markdown]
# # **Evaluating The Performance Of The Model**

# %%
# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Precision
precision = precision_score(y_test, y_pred, average='weighted')
print(f"Precision: {precision:.4f}")

# Recall
recall = recall_score(y_test, y_pred, average='weighted')
print(f"Recall: {recall:.4f}")

# F1-score
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.9803
# Precision: 0.9807
# Recall: 0.9803
# F1-score: 0.9796
